# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from utils.utils import get_labels, load_population_metadata, get_mobil_feat

# %%
#get_labels('ON').head()
df2 = load_population_metadata()

# %%
# fetch labels 
df = get_labels(country_code='ON')
#df = df.loc[:'2022-01-31', :]
df
# Out:
#             TotalCases  TotalHospitalized  TotalICU
# date
# 2020-04-09        5759              632.0     478.0
# 2020-04-10        6237              673.0     477.0
# 2020-04-11        6648              691.0     472.0
# 2020-04-12        7049              738.0     457.0
# 2020-04-13        7470              760.0     466.0
# ...                ...                ...       ...
# 2022-02-22     1090101             1038.0     319.0
# 2022-02-23     1091526             1106.0     319.0
# 2022-02-24     1093930             1066.0     302.0
# 2022-02-25     1096357             1003.0     297.0
# 2022-02-26     1098695             1024.0     284.0
#
# [689 rows x 3 columns]

# %%
# fetch mobil
df2 = get_mobil_feat(country_code='ON', averaging=7, normalize=True)
df2.plot()

# index starts when label starts
df2 = df2.loc[df.index[0]:'2022-01-31', :]
df2
# Out:
#             mobility_retail_and_recreation  mobility_transit_stations  \
# date
# 2020-04-09                       -1.163253                  -1.385859
# 2020-04-10                       -3.360867                  -1.507414
# 2020-04-11                       -1.741572                  -1.496363
# 2020-04-12                       -3.245203                  -1.529514
# 2020-04-13                       -1.972900                  -1.584767
# ...                                    ...                        ...
# 2022-01-27                       -0.295774                  -0.435521
# 2022-01-28                       -0.353606                  -0.424471
# 2022-01-29                       -0.180110                  -0.402370
# 2022-01-30                       -0.064446                  -0.358168
# 2022-01-31                        0.224714                  -0.302916
#
#             mobility_workplaces
# date
# 2020-04-09            -2.122680
# 2020-04-10            -2.421685
# ...
